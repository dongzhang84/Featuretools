# %% [markdown]
# # Titanic FeatureTools version 2
#
# Follow this blog:
#
# https://medium.com/dataexplorations/tool-review-can-featuretools-simplify-the-process-of-feature-engineering-5d165100b0c3
#
# Or this github:
#
# https://github.com/ag2816/TitanicKaggle/blob/master/Titanic_FeatureTools.ipynb

# %%
import featuretools as ft
import featuretools.variable_types as vtypes

import pandas as pd
import numpy as np

#visualization
import seaborn as sns
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')

#import sklearn
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.metrics import(
    classification_report, confusion_matrix, accuracy_score, mean_squared_error, mean_absolute_error
)


from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import (
    StandardScaler, LabelBinarizer, FunctionTransformer,PolynomialFeatures, OrdinalEncoder
)

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

from sklearn.feature_selection import (
    VarianceThreshold, SelectKBest, SelectPercentile, 
    SelectFromModel, f_regression, RFECV
)

from sklearn.impute import SimpleImputer
from sklearn_pandas import DataFrameMapper
from sklearn.model_selection import GridSearchCV

from sklearn.base import TransformerMixin, BaseEstimator

from sklearn.pipeline import Pipeline, FeatureUnion

# %% [markdown]
# # Load Data

# %%
titanic_df = pd.read_csv('titanic/train.csv')
test_df= pd.read_csv('titanic/test.csv')

# %%
# split training to train and test

X_train, X_test, y_train, y_test = train_test_split(titanic_df.iloc[:,:], titanic_df['Survived'], random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
X_train.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 298          299         1       1            Saalfeld, Mr. Adolphe    male
# 884          885         0       3           Sutehall, Mr. Henry Jr    male
# 247          248         1       2  Hamalainen, Mrs. William (Anna)  female
# 478          479         0       3        Karlsson, Mr. Nils August    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
#
#        Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# 298    NaN      0      0            19988   30.5000     C106        S
# 884  25.00      0      0  SOTON/OQ 392076    7.0500      NaN        S
# 247  24.00      0      2           250649   14.5000      NaN        S
# 478  22.00      0      0           350060    7.5208      NaN        S
# 305   0.92      1      2           113781  151.5500  C22 C26        S

# %%
X_train.shape, X_test.shape
# Out:
# ((668, 12), (223, 12))

# %%
X_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            132
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          519
# Embarked         2
# dtype: int64

# %% [markdown]
# # FE for original fields

# %%
X_train['Age'].fillna(X_train['Age'].median(), inplace = True)
X_train['Embarked'].fillna(X_train['Embarked'].mode()[0], inplace = True)
X_train['Fare'].fillna(X_train['Fare'].median(), inplace = True)

# %%
X_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          519
# Embarked         0
# dtype: int64

# %%
X_test['Age'].fillna(X_train['Age'].median(), inplace = True)
X_test['Embarked'].fillna(X_train['Embarked'].mode()[0], inplace = True)
X_test['Fare'].fillna(X_train['Fare'].median(), inplace = True)

# %%
X_test.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          168
# Embarked         0
# dtype: int64

# %%
X_train['family_count'] = X_train['Parch'] + X_train['SibSp']
X_test['family_count'] = X_test['Parch'] + X_test['SibSp']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

le.fit(X_train['Sex'])
X_train['Sex'] = le.transform(X_train['Sex'])
X_test['Sex'] = le.transform(X_test['Sex'])

le = LabelEncoder()

le.fit(X_train['Embarked'])
X_train['Embarked'] = le.transform(X_train['Embarked'])
X_test['Embarked'] = le.transform(X_test['Embarked'])

# %%
X_train = X_train.drop(columns=['Survived','Parch','SibSp', 'Name','Ticket','Cabin'], axis=1)
X_test = X_test.drop(columns=['Survived', 'Parch','SibSp', 'Name', 'Ticket','Cabin'], axis=1)

# %%
X_train_orig =X_train.copy()
X_train
# Out:
#      PassengerId  Pclass  Sex    Age      Fare  Embarked  family_count
# 298          299       1    1  28.00   30.5000         2             0
# 884          885       3    1  25.00    7.0500         2             0
# 247          248       2    0  24.00   14.5000         2             2
# 478          479       3    1  22.00    7.5208         2             0
# 305          306       1    1   0.92  151.5500         2             3
# ..           ...     ...  ...    ...       ...       ...           ...
# 106          107       3    0  21.00    7.6500         2             0
# 270          271       1    1  28.00   31.0000         2             0
# 860          861       3    1  41.00   14.1083         2             2
# 435          436       1    0  14.00  120.0000         2             3
# 102          103       1    1  21.00   77.2875         2             1
#
# [668 rows x 7 columns]

# %%
# save a copy of this dataframe for later reference
X_test_orig = X_test.copy()
X_test
# Out:
#      PassengerId  Pclass  Sex   Age     Fare  Embarked  family_count
# 709          710       3    1  28.0  15.2458         0             2
# 439          440       2    1  31.0  10.5000         2             0
# 840          841       3    1  20.0   7.9250         2             0
# 720          721       2    0   6.0  33.0000         2             1
# 39            40       3    0  14.0  11.2417         0             1
# ..           ...     ...  ...   ...      ...       ...           ...
# 880          881       2    0  25.0  26.0000         2             1
# 425          426       3    1  28.0   7.2500         2             0
# 101          102       3    1  28.0   7.8958         2             0
# 199          200       2    0  24.0  13.0000         2             0
# 424          425       3    1  18.0  20.2125         2             2
#
# [223 rows x 7 columns]

# %% [markdown]
# # Load FeatureTools

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(primitives[primitives['type'] == 'aggregation'].shape[0])
# Out:
#                 name         type  dask_compatible  koalas_compatible  \
# 0                all  aggregation             True              False
# 1                min  aggregation             True               True
# 2               last  aggregation            False              False
# 3               mean  aggregation             True               True
# 4       percent_true  aggregation             True              False
# 5            entropy  aggregation            False              False
# 6                std  aggregation             True               True
# 7             median  aggregation            False              False
# 8   avg_time_between  aggregation            False              False
# 9                sum  aggregation             True               True
# 10          num_true  aggregation             True              False
# 11             trend  aggregation            False              False
# 12               max  aggregation             True               True
# 13   time_since_last  aggregation            False              False
# 14  time_since_first  aggregation            False              False
# 15               any  aggregation             True              False
# 16              mode  aggregation            False              False
# 17             first  aggregation            False              False
# 18              skew  aggregation            False              False
# 19     n_most_common  aggregation            False              False
# 20             count  aggregation             True               True
# 21        num_unique  aggregation             True               True
#
#                                                                         description  \
# 0                                    Calculates if all values are 'True' in a list.
# 1                             Calculates the smallest value, ignoring `NaN` values.
# 2                                              Determines the last value in a list.
# 3                                        Computes the average for a list of values.
# 4                                          Determines the percent of `True` values.
# 5                                 Calculates the entropy for a categorical variable
# 6               Computes the dispersion relative to the mean value, ignoring `NaN`.
# 7                             Determines the middlemost number in a list of values.
# 8                Computes the average number of seconds between consecutive events.
# 9                                    Calculates the total addition, ignoring `NaN`.
# 10                                              Counts the number of `True` values.
# 11                                    Calculates the trend of a variable over time.
# 12                             Calculates the highest value, ignoring `NaN` values.
# 13        Calculates the time elapsed since the last datetime (default in seconds).
# 14               Calculates the time elapsed since the first datetime (in seconds).
# 15                                     Determines if any value is 'True' in a list.
# 16                                     Determines the most commonly repeated value.
# 17                                            Determines the first value in a list.
# 18  Computes the extent to which a distribution differs from a normal distribution.
# 19                                         Determines the `n` most common elements.
# 20                          Determines the total number of values, excluding `NaN`.
# 21                 Determines the number of distinct values, ignoring `NaN` values.
#
#                   valid_inputs return_type
# 0                      Boolean     Boolean
# 1                      Numeric     Numeric
# 2                     Variable        None
# 3                      Numeric     Numeric
# 4                      Boolean     Numeric
# 5                  Categorical     Numeric
# 6                      Numeric     Numeric
# 7                      Numeric     Numeric
# 8            DatetimeTimeIndex     Numeric
# 9                      Numeric     Numeric
# 10                     Boolean     Numeric
# 11  DatetimeTimeIndex, Numeric     Numeric
# 12                     Numeric     Numeric
# 13           DatetimeTimeIndex     Numeric
# 14           DatetimeTimeIndex     Numeric
# 15                     Boolean     Boolean
# 16                    Discrete        None
# 17                    Variable        None
# 18                     Numeric     Numeric
# 19                    Discrete    Discrete
# 20                       Index     Numeric
# 21                    Discrete     Numeric

# %%
primitives[primitives['type'] == 'transform'].head(primitives[primitives['type'] == 'transform'].shape[0])
# Out:
#                                name       type  dask_compatible  \
# 22                           minute  transform             True
# 23  scalar_subtract_numeric_feature  transform             True
# 24     greater_than_equal_to_scalar  transform             True
# 25               add_numeric_scalar  transform             True
# 26                             hour  transform             True
# ..                              ...        ...              ...
# 79                             diff  transform            False
# 80                divide_by_feature  transform             True
# 81                            month  transform             True
# 82                 less_than_scalar  transform             True
# 83                        cum_count  transform            False
#
#     koalas_compatible  \
# 22               True
# 23               True
# 24               True
# 25               True
# 26               True
# ..                ...
# 79              False
# 80               True
# 81               True
# 82               True
# 83              False
#
#                                                           description  \
# 22                        Determines the minutes value of a datetime.
# 23               Subtract each value in the list from a given scalar.
# 24  Determines if values are greater than or equal to a given scalar.
# 25                            Add a scalar to each value in the list.
# 26                           Determines the hour value of a datetime.
# ..                                                                ...
# 79         Compute the difference between the value in a list and the
# 80                         Divide a scalar by each value in the list.
# 81                          Determines the month value of a datetime.
# 82                 Determines if values are less than a given scalar.
# 83                                   Calculates the cumulative count.
#
#                   valid_inputs return_type
# 22                    Datetime     Numeric
# 23                     Numeric     Numeric
# 24  Datetime, Ordinal, Numeric     Boolean
# 25                     Numeric     Numeric
# 26                    Datetime     Ordinal
# ..                         ...         ...
# 79                     Numeric     Numeric
# 80                     Numeric     Numeric
# 81                    Datetime     Ordinal
# 82  Datetime, Ordinal, Numeric     Boolean
# 83                Id, Discrete     Numeric
#
# [62 rows x 7 columns]

# %%
# reset indices

X_train_orig.reset_index(drop=True, inplace=True)
X_test_orig.reset_index(drop=True, inplace=True)
X_train_orig.head()
# Out:
#    PassengerId  Pclass  Sex    Age      Fare  Embarked  family_count
# 0          299       1    1  28.00   30.5000         2             0
# 1          885       3    1  25.00    7.0500         2             0
# 2          248       2    0  24.00   14.5000         2             2
# 3          479       3    1  22.00    7.5208         2             0
# 4          306       1    1   0.92  151.5500         2             3

# %% [markdown]
# ## FE by FeatureTools

# %%
# creating and entity set 'es'
es = ft.EntitySet(id = 'Survivors')
variable_types = { 
      'Sex': vtypes.Categorical,
      'Pclass': vtypes.Categorical,
      'Embarked': vtypes.Categorical}

es.entity_from_dataframe(entity_id = 'Passengers', dataframe = X_train_orig, index = 'Id', variable_types=variable_types)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/featuretools/entityset/entity.py:462: UserWarning: index Id not found in dataframe, creating new integer column
#   warnings.warn("index {} not found in dataframe, creating new "
# Entityset: Survivors
#   Entities:
#     Passengers [Rows: 668, Columns: 8]
#   Relationships:
#     No relationships

# %%
es["Passengers"].variables
# Out:
# [<Variable: Id (dtype = index)>,
#  <Variable: PassengerId (dtype = numeric)>,
#  <Variable: Age (dtype = numeric)>,
#  <Variable: Fare (dtype = numeric)>,
#  <Variable: family_count (dtype = numeric)>,
#  <Variable: Sex (dtype = categorical)>,
#  <Variable: Pclass (dtype = categorical)>,
#  <Variable: Embarked (dtype = categorical)>]

# %%
es = es.normalize_entity(base_entity_id='Passengers', new_entity_id='Pclass', index='Pclass')
es
# Out:
# Entityset: Survivors
#   Entities:
#     Passengers [Rows: 668, Columns: 8]
#     Pclass [Rows: 3, Columns: 1]
#   Relationships:
#     Passengers.Pclass -> Pclass.Pclass

# %%
feature_matrix, feature_names = ft.dfs(entityset=es, 
    target_entity = 'Passengers', 
    max_depth = 2, 
    verbose = 3, 
    n_jobs = 1,
    ignore_variables={'Passengers':['PassengerId']})
# Out:
# Built 29 features
# Elapsed: 00:00 | Progress: 100%|████████████████████████████████████████████████

# %%
feature_matrix
# Out:
#        Age      Fare  family_count  Sex  Pclass  Embarked  \
# Id
# 0    28.00   30.5000             0    1       1         2
# 1    25.00    7.0500             0    1       3         2
# 2    24.00   14.5000             2    0       2         2
# 3    22.00    7.5208             0    1       3         2
# 4     0.92  151.5500             3    1       1         2
# ..     ...       ...           ...  ...     ...       ...
# 663  21.00    7.6500             0    0       3         2
# 664  28.00   31.0000             0    1       1         2
# 665  41.00   14.1083             2    1       3         2
# 666  14.00  120.0000             3    0       1         2
# 667  21.00   77.2875             1    1       1         2
#
#      Pclass.COUNT(Passengers)  Pclass.MAX(Passengers.Age)  \
# Id
# 0                         152                        80.0
# 1                         375                        74.0
# 2                         141                        70.0
# 3                         375                        74.0
# 4                         152                        80.0
# ..                        ...                         ...
# 663                       375                        74.0
# 664                       152                        80.0
# 665                       375                        74.0
# 666                       152                        80.0
# 667                       152                        80.0
#
#      Pclass.MAX(Passengers.Fare)  Pclass.MAX(Passengers.family_count)  ...  \
# Id                                                                     ...
# 0                       512.3292                                    5  ...
# 1                        69.5500                                   10  ...
# 2                        73.5000                                    5  ...
# 3                        69.5500                                   10  ...
# 4                       512.3292                                    5  ...
# ..                           ...                                  ...  ...
# 663                      69.5500                                   10  ...
# 664                     512.3292                                    5  ...
# 665                      69.5500                                   10  ...
# 666                     512.3292                                    5  ...
# 667                     512.3292                                    5  ...
#
#      Pclass.NUM_UNIQUE(Passengers.Sex)  Pclass.SKEW(Passengers.Age)  \
# Id
# 0                                    2                     0.259387
# 1                                    2                     0.211083
# 2                                    2                     0.133481
# 3                                    2                     0.211083
# 4                                    2                     0.259387
# ..                                 ...                          ...
# 663                                  2                     0.211083
# 664                                  2                     0.259387
# 665                                  2                     0.211083
# 666                                  2                     0.259387
# 667                                  2                     0.259387
#
#      Pclass.SKEW(Passengers.Fare)  Pclass.SKEW(Passengers.family_count)  \
# Id
# 0                        2.900362                              1.960429
# 1                        2.703980                              2.564656
# 2                        1.957192                              1.234036
# 3                        2.703980                              2.564656
# 4                        2.900362                              1.960429
# ..                            ...                                   ...
# 663                      2.703980                              2.564656
# 664                      2.900362                              1.960429
# 665                      2.703980                              2.564656
# 666                      2.900362                              1.960429
# 667                      2.900362                              1.960429
#
#      Pclass.STD(Passengers.Age)  Pclass.STD(Passengers.Fare)  \
# Id
# 0                     14.234234                    84.524889
# 1                     10.574068                    12.555034
# 2                     13.996094                    13.119260
# 3                     10.574068                    12.555034
# 4                     14.234234                    84.524889
# ..                          ...                          ...
# 663                   10.574068                    12.555034
# 664                   14.234234                    84.524889
# 665                   10.574068                    12.555034
# 666                   14.234234                    84.524889
# 667                   14.234234                    84.524889
#
#      Pclass.STD(Passengers.family_count)  Pclass.SUM(Passengers.Age)  \
# Id
# 0                               1.091313                     5598.92
# 1                               2.037534                     9670.92
# 2                               1.101395                     4196.00
# 3                               2.037534                     9670.92
# 4                               1.091313                     5598.92
# ..                                   ...                         ...
# 663                             2.037534                     9670.92
# 664                             1.091313                     5598.92
# 665                             2.037534                     9670.92
# 666                             1.091313                     5598.92
# 667                             1.091313                     5598.92
#
#      Pclass.SUM(Passengers.Fare)  Pclass.SUM(Passengers.family_count)
# Id
# 0                     13352.9125                                  119
# 1                      5236.2036                                  386
# 2                      2906.7209                                  114
# 3                      5236.2036                                  386
# 4                     13352.9125                                  119
# ..                           ...                                  ...
# 663                    5236.2036                                  386
# 664                   13352.9125                                  119
# 665                    5236.2036                                  386
# 666                   13352.9125                                  119
# 667                   13352.9125                                  119
#
# [668 rows x 29 columns]

# %%
feature_names
# Out:
# [<Feature: Age>,
#  <Feature: Fare>,
#  <Feature: family_count>,
#  <Feature: Sex>,
#  <Feature: Pclass>,
#  <Feature: Embarked>,
#  <Feature: Pclass.COUNT(Passengers)>,
#  <Feature: Pclass.MAX(Passengers.Age)>,
#  <Feature: Pclass.MAX(Passengers.Fare)>,
#  <Feature: Pclass.MAX(Passengers.family_count)>,
#  <Feature: Pclass.MEAN(Passengers.Age)>,
#  <Feature: Pclass.MEAN(Passengers.Fare)>,
#  <Feature: Pclass.MEAN(Passengers.family_count)>,
#  <Feature: Pclass.MIN(Passengers.Age)>,
#  <Feature: Pclass.MIN(Passengers.Fare)>,
#  <Feature: Pclass.MIN(Passengers.family_count)>,
#  <Feature: Pclass.MODE(Passengers.Embarked)>,
#  <Feature: Pclass.MODE(Passengers.Sex)>,
#  <Feature: Pclass.NUM_UNIQUE(Passengers.Embarked)>,
#  <Feature: Pclass.NUM_UNIQUE(Passengers.Sex)>,
#  <Feature: Pclass.SKEW(Passengers.Age)>,
#  <Feature: Pclass.SKEW(Passengers.Fare)>,
#  <Feature: Pclass.SKEW(Passengers.family_count)>,
#  <Feature: Pclass.STD(Passengers.Age)>,
#  <Feature: Pclass.STD(Passengers.Fare)>,
#  <Feature: Pclass.STD(Passengers.family_count)>,
#  <Feature: Pclass.SUM(Passengers.Age)>,
#  <Feature: Pclass.SUM(Passengers.Fare)>,
#  <Feature: Pclass.SUM(Passengers.family_count)>]

# %%
X_train=feature_matrix.copy() # save the generated features back into our X_Train
feature_matrix.head().T
# Out:
# Id                                                 0            1  \
# Age                                        28.000000    25.000000
# Fare                                       30.500000     7.050000
# family_count                                0.000000     0.000000
# Sex                                         1.000000     1.000000
# Pclass                                      1.000000     3.000000
# Embarked                                    2.000000     2.000000
# Pclass.COUNT(Passengers)                  152.000000   375.000000
# Pclass.MAX(Passengers.Age)                 80.000000    74.000000
# Pclass.MAX(Passengers.Fare)               512.329200    69.550000
# Pclass.MAX(Passengers.family_count)         5.000000    10.000000
# Pclass.MEAN(Passengers.Age)                36.835000    25.789120
# Pclass.MEAN(Passengers.Fare)               87.848109    13.963210
# Pclass.MEAN(Passengers.family_count)        0.782895     1.029333
# Pclass.MIN(Passengers.Age)                  0.920000     0.420000
# Pclass.MIN(Passengers.Fare)                 0.000000     0.000000
# Pclass.MIN(Passengers.family_count)         0.000000     0.000000
# Pclass.MODE(Passengers.Embarked)            2.000000     2.000000
# Pclass.MODE(Passengers.Sex)                 1.000000     1.000000
# Pclass.NUM_UNIQUE(Passengers.Embarked)      3.000000     3.000000
# Pclass.NUM_UNIQUE(Passengers.Sex)           2.000000     2.000000
# Pclass.SKEW(Passengers.Age)                 0.259387     0.211083
# Pclass.SKEW(Passengers.Fare)                2.900362     2.703980
# Pclass.SKEW(Passengers.family_count)        1.960429     2.564656
# Pclass.STD(Passengers.Age)                 14.234234    10.574068
# Pclass.STD(Passengers.Fare)                84.524889    12.555034
# Pclass.STD(Passengers.family_count)         1.091313     2.037534
# Pclass.SUM(Passengers.Age)               5598.920000  9670.920000
# Pclass.SUM(Passengers.Fare)             13352.912500  5236.203600
# Pclass.SUM(Passengers.family_count)       119.000000   386.000000
#
# Id                                                2            3             4
# Age                                       24.000000    22.000000      0.920000
# Fare                                      14.500000     7.520800    151.550000
# family_count                               2.000000     0.000000      3.000000
# Sex                                        0.000000     1.000000      1.000000
# Pclass                                     2.000000     3.000000      1.000000
# Embarked                                   2.000000     2.000000      2.000000
# Pclass.COUNT(Passengers)                 141.000000   375.000000    152.000000
# Pclass.MAX(Passengers.Age)                70.000000    74.000000     80.000000
# Pclass.MAX(Passengers.Fare)               73.500000    69.550000    512.329200
# Pclass.MAX(Passengers.family_count)        5.000000    10.000000      5.000000
# Pclass.MEAN(Passengers.Age)               29.758865    25.789120     36.835000
# Pclass.MEAN(Passengers.Fare)              20.615042    13.963210     87.848109
# Pclass.MEAN(Passengers.family_count)       0.808511     1.029333      0.782895
# Pclass.MIN(Passengers.Age)                 0.670000     0.420000      0.920000
# Pclass.MIN(Passengers.Fare)                0.000000     0.000000      0.000000
# Pclass.MIN(Passengers.family_count)        0.000000     0.000000      0.000000
# Pclass.MODE(Passengers.Embarked)           2.000000     2.000000      2.000000
# Pclass.MODE(Passengers.Sex)                1.000000     1.000000      1.000000
# Pclass.NUM_UNIQUE(Passengers.Embarked)     3.000000     3.000000      3.000000
# Pclass.NUM_UNIQUE(Passengers.Sex)          2.000000     2.000000      2.000000
# Pclass.SKEW(Passengers.Age)                0.133481     0.211083      0.259387
# Pclass.SKEW(Passengers.Fare)               1.957192     2.703980      2.900362
# Pclass.SKEW(Passengers.family_count)       1.234036     2.564656      1.960429
# Pclass.STD(Passengers.Age)                13.996094    10.574068     14.234234
# Pclass.STD(Passengers.Fare)               13.119260    12.555034     84.524889
# Pclass.STD(Passengers.family_count)        1.101395     2.037534      1.091313
# Pclass.SUM(Passengers.Age)              4196.000000  9670.920000   5598.920000
# Pclass.SUM(Passengers.Fare)             2906.720900  5236.203600  13352.912500
# Pclass.SUM(Passengers.family_count)      114.000000   386.000000    119.000000

# %%
feature_matrix_enc, features_enc = ft.encode_features(feature_matrix, feature_names, include_unknown=False)

# %%
features_enc
# Out:
# [<Feature: Age>,
#  <Feature: Fare>,
#  <Feature: family_count>,
#  <Feature: Sex = 1>,
#  <Feature: Sex = 0>,
#  <Feature: Pclass = 3>,
#  <Feature: Pclass = 1>,
#  <Feature: Pclass = 2>,
#  <Feature: Embarked = 2>,
#  <Feature: Embarked = 0>,
#  <Feature: Embarked = 1>,
#  <Feature: Pclass.COUNT(Passengers)>,
#  <Feature: Pclass.MAX(Passengers.Age)>,
#  <Feature: Pclass.MAX(Passengers.Fare)>,
#  <Feature: Pclass.MAX(Passengers.family_count)>,
#  <Feature: Pclass.MEAN(Passengers.Age)>,
#  <Feature: Pclass.MEAN(Passengers.Fare)>,
#  <Feature: Pclass.MEAN(Passengers.family_count)>,
#  <Feature: Pclass.MIN(Passengers.Age)>,
#  <Feature: Pclass.MIN(Passengers.Fare)>,
#  <Feature: Pclass.MIN(Passengers.family_count)>,
#  <Feature: Pclass.MODE(Passengers.Embarked) = 2>,
#  <Feature: Pclass.MODE(Passengers.Sex) = 1>,
#  <Feature: Pclass.NUM_UNIQUE(Passengers.Embarked)>,
#  <Feature: Pclass.NUM_UNIQUE(Passengers.Sex)>,
#  <Feature: Pclass.SKEW(Passengers.Age)>,
#  <Feature: Pclass.SKEW(Passengers.Fare)>,
#  <Feature: Pclass.SKEW(Passengers.family_count)>,
#  <Feature: Pclass.STD(Passengers.Age)>,
#  <Feature: Pclass.STD(Passengers.Fare)>,
#  <Feature: Pclass.STD(Passengers.family_count)>,
#  <Feature: Pclass.SUM(Passengers.Age)>,
#  <Feature: Pclass.SUM(Passengers.Fare)>,
#  <Feature: Pclass.SUM(Passengers.family_count)>]

# %%
feature_matrix_enc
# Out:
#        Age      Fare  family_count  Sex = 1  Sex = 0  Pclass = 3  Pclass = 1  \
# Id
# 0    28.00   30.5000             0     True    False       False        True
# 1    25.00    7.0500             0     True    False        True       False
# 2    24.00   14.5000             2    False     True       False       False
# 3    22.00    7.5208             0     True    False        True       False
# 4     0.92  151.5500             3     True    False       False        True
# ..     ...       ...           ...      ...      ...         ...         ...
# 663  21.00    7.6500             0    False     True        True       False
# 664  28.00   31.0000             0     True    False       False        True
# 665  41.00   14.1083             2     True    False        True       False
# 666  14.00  120.0000             3    False     True       False        True
# 667  21.00   77.2875             1     True    False       False        True
#
#      Pclass = 2  Embarked = 2  Embarked = 0  ...  \
# Id                                           ...
# 0         False          True         False  ...
# 1         False          True         False  ...
# 2          True          True         False  ...
# 3         False          True         False  ...
# 4         False          True         False  ...
# ..          ...           ...           ...  ...
# 663       False          True         False  ...
# 664       False          True         False  ...
# 665       False          True         False  ...
# 666       False          True         False  ...
# 667       False          True         False  ...
#
#      Pclass.NUM_UNIQUE(Passengers.Sex)  Pclass.SKEW(Passengers.Age)  \
# Id
# 0                                    2                     0.259387
# 1                                    2                     0.211083
# 2                                    2                     0.133481
# 3                                    2                     0.211083
# 4                                    2                     0.259387
# ..                                 ...                          ...
# 663                                  2                     0.211083
# 664                                  2                     0.259387
# 665                                  2                     0.211083
# 666                                  2                     0.259387
# 667                                  2                     0.259387
#
#      Pclass.SKEW(Passengers.Fare)  Pclass.SKEW(Passengers.family_count)  \
# Id
# 0                        2.900362                              1.960429
# 1                        2.703980                              2.564656
# 2                        1.957192                              1.234036
# 3                        2.703980                              2.564656
# 4                        2.900362                              1.960429
# ..                            ...                                   ...
# 663                      2.703980                              2.564656
# 664                      2.900362                              1.960429
# 665                      2.703980                              2.564656
# 666                      2.900362                              1.960429
# 667                      2.900362                              1.960429
#
#      Pclass.STD(Passengers.Age)  Pclass.STD(Passengers.Fare)  \
# Id
# 0                     14.234234                    84.524889
# 1                     10.574068                    12.555034
# 2                     13.996094                    13.119260
# 3                     10.574068                    12.555034
# 4                     14.234234                    84.524889
# ..                          ...                          ...
# 663                   10.574068                    12.555034
# 664                   14.234234                    84.524889
# 665                   10.574068                    12.555034
# 666                   14.234234                    84.524889
# 667                   14.234234                    84.524889
#
#      Pclass.STD(Passengers.family_count)  Pclass.SUM(Passengers.Age)  \
# Id
# 0                               1.091313                     5598.92
# 1                               2.037534                     9670.92
# 2                               1.101395                     4196.00
# 3                               2.037534                     9670.92
# 4                               1.091313                     5598.92
# ..                                   ...                         ...
# 663                             2.037534                     9670.92
# 664                             1.091313                     5598.92
# 665                             2.037534                     9670.92
# 666                             1.091313                     5598.92
# 667                             1.091313                     5598.92
#
#      Pclass.SUM(Passengers.Fare)  Pclass.SUM(Passengers.family_count)
# Id
# 0                     13352.9125                                  119
# 1                      5236.2036                                  386
# 2                      2906.7209                                  114
# 3                      5236.2036                                  386
# 4                     13352.9125                                  119
# ..                           ...                                  ...
# 663                    5236.2036                                  386
# 664                   13352.9125                                  119
# 665                    5236.2036                                  386
# 666                   13352.9125                                  119
# 667                   13352.9125                                  119
#
# [668 rows x 34 columns]

# %%
X_train = feature_matrix_enc.copy()
X_train.head()
# Out:
#       Age      Fare  family_count  Sex = 1  Sex = 0  Pclass = 3  Pclass = 1  \
# Id
# 0   28.00   30.5000             0     True    False       False        True
# 1   25.00    7.0500             0     True    False        True       False
# 2   24.00   14.5000             2    False     True       False       False
# 3   22.00    7.5208             0     True    False        True       False
# 4    0.92  151.5500             3     True    False       False        True
#
#     Pclass = 2  Embarked = 2  Embarked = 0  ...  \
# Id                                          ...
# 0        False          True         False  ...
# 1        False          True         False  ...
# 2         True          True         False  ...
# 3        False          True         False  ...
# 4        False          True         False  ...
#
#     Pclass.NUM_UNIQUE(Passengers.Sex)  Pclass.SKEW(Passengers.Age)  \
# Id
# 0                                   2                     0.259387
# 1                                   2                     0.211083
# 2                                   2                     0.133481
# 3                                   2                     0.211083
# 4                                   2                     0.259387
#
#     Pclass.SKEW(Passengers.Fare)  Pclass.SKEW(Passengers.family_count)  \
# Id
# 0                       2.900362                              1.960429
# 1                       2.703980                              2.564656
# 2                       1.957192                              1.234036
# 3                       2.703980                              2.564656
# 4                       2.900362                              1.960429
#
#     Pclass.STD(Passengers.Age)  Pclass.STD(Passengers.Fare)  \
# Id
# 0                    14.234234                    84.524889
# 1                    10.574068                    12.555034
# 2                    13.996094                    13.119260
# 3                    10.574068                    12.555034
# 4                    14.234234                    84.524889
#
#     Pclass.STD(Passengers.family_count)  Pclass.SUM(Passengers.Age)  \
# Id
# 0                              1.091313                     5598.92
# 1                              2.037534                     9670.92
# 2                              1.101395                     4196.00
# 3                              2.037534                     9670.92
# 4                              1.091313                     5598.92
#
#     Pclass.SUM(Passengers.Fare)  Pclass.SUM(Passengers.family_count)
# Id
# 0                    13352.9125                                  119
# 1                     5236.2036                                  386
# 2                     2906.7209                                  114
# 3                     5236.2036                                  386
# 4                    13352.9125                                  119
#
# [5 rows x 34 columns]

# %%
X_train_orig.head()
# Out:
#    Id  PassengerId  Pclass  Sex    Age      Fare  Embarked  family_count
# 0   0          299       1    1  28.00   30.5000         2             0
# 1   1          885       3    1  25.00    7.0500         2             0
# 2   2          248       2    0  24.00   14.5000         2             2
# 3   3          479       3    1  22.00    7.5208         2             0
# 4   4          306       1    1   0.92  151.5500         2             3

# %% [markdown]
# ## Save FE and load Test data

# %%
#creating and entity set 'es'
es_tst = ft.EntitySet(id = 'Survivors')
# adding a dataframe 
es_tst.entity_from_dataframe(entity_id = 'Passengers', dataframe = X_test_orig, index = 'Id')
# add PCLass entity
es_tst = es_tst.normalize_entity(base_entity_id='Passengers', new_entity_id='Pclass', index='Pclass')
es_tst
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/featuretools/entityset/entity.py:462: UserWarning: index Id not found in dataframe, creating new integer column
#   warnings.warn("index {} not found in dataframe, creating new "
# Entityset: Survivors
#   Entities:
#     Passengers [Rows: 223, Columns: 8]
#     Pclass [Rows: 3, Columns: 1]
#   Relationships:
#     Passengers.Pclass -> Pclass.Pclass

# %%
feature_matrix_tst = ft.calculate_feature_matrix(features=features_enc, entityset=es_tst)

# %%
feature_matrix_tst
# Out:
#       Age     Fare  family_count  Sex = 1  Sex = 0  Pclass = 3  Pclass = 1  \
# Id
# 0    28.0  15.2458             2     True    False        True       False
# 1    31.0  10.5000             0     True    False       False       False
# 2    20.0   7.9250             0     True    False        True       False
# 3     6.0  33.0000             1    False     True       False       False
# 4    14.0  11.2417             1    False     True        True       False
# ..    ...      ...           ...      ...      ...         ...         ...
# 218  25.0  26.0000             1    False     True       False       False
# 219  28.0   7.2500             0     True    False        True       False
# 220  28.0   7.8958             0     True    False        True       False
# 221  24.0  13.0000             0    False     True       False       False
# 222  18.0  20.2125             2     True    False        True       False
#
#      Pclass = 2  Embarked = 2  Embarked = 0  ...  \
# Id                                           ...
# 0         False         False          True  ...
# 1          True          True         False  ...
# 2         False          True         False  ...
# 3          True          True         False  ...
# 4         False         False          True  ...
# ..          ...           ...           ...  ...
# 218        True          True         False  ...
# 219       False          True         False  ...
# 220       False          True         False  ...
# 221        True          True         False  ...
# 222       False          True         False  ...
#
#      Pclass.NUM_UNIQUE(Passengers.Sex)  Pclass.SKEW(Passengers.Age)  \
# Id
# 0                                    2                     0.690926
# 1                                    2                     0.315440
# 2                                    2                     0.690926
# 3                                    2                     0.315440
# 4                                    2                     0.690926
# ..                                 ...                          ...
# 218                                  2                     0.315440
# 219                                  2                     0.690926
# 220                                  2                     0.690926
# 221                                  2                     0.315440
# 222                                  2                     0.690926
#
#      Pclass.SKEW(Passengers.Fare)  Pclass.SKEW(Passengers.family_count)  \
# Id
# 0                        2.147037                              1.852647
# 1                        2.289693                              0.864271
# 2                        2.147037                              1.852647
# 3                        2.289693                              0.864271
# 4                        2.147037                              1.852647
# ..                            ...                                   ...
# 218                      2.289693                              0.864271
# 219                      2.147037                              1.852647
# 220                      2.147037                              1.852647
# 221                      2.289693                              0.864271
# 222                      2.147037                              1.852647
#
#      Pclass.STD(Passengers.Age)  Pclass.STD(Passengers.Fare)  \
# Id
# 0                     11.122151                     8.792546
# 1                     12.275540                    14.513892
# 2                     11.122151                     8.792546
# 3                     12.275540                    14.513892
# 4                     11.122151                     8.792546
# ..                          ...                          ...
# 218                   12.275540                    14.513892
# 219                   11.122151                     8.792546
# 220                   11.122151                     8.792546
# 221                   12.275540                    14.513892
# 222                   11.122151                     8.792546
#
#      Pclass.STD(Passengers.family_count)  Pclass.SUM(Passengers.Age)  \
# Id
# 0                               1.659171                     3062.00
# 1                               0.887342                     1280.83
# 2                               1.659171                     3062.00
# 3                               0.887342                     1280.83
# 4                               1.659171                     3062.00
# ..                                   ...                         ...
# 218                             0.887342                     1280.83
# 219                             1.659171                     3062.00
# 220                             1.659171                     3062.00
# 221                             0.887342                     1280.83
# 222                             1.659171                     3062.00
#
#      Pclass.SUM(Passengers.Fare)  Pclass.SUM(Passengers.family_count)
# Id
# 0                      1478.4915                                  109
# 1                       895.1208                                   30
# 2                      1478.4915                                  109
# 3                       895.1208                                   30
# 4                      1478.4915                                  109
# ..                           ...                                  ...
# 218                     895.1208                                   30
# 219                    1478.4915                                  109
# 220                    1478.4915                                  109
# 221                     895.1208                                   30
# 222                    1478.4915                                  109
#
# [223 rows x 34 columns]

# %%
X_test = feature_matrix_tst.copy()
X_test.head()
# Out:
#      Age     Fare  family_count  Sex = 1  Sex = 0  Pclass = 3  Pclass = 1  \
# Id
# 0   28.0  15.2458             2     True    False        True       False
# 1   31.0  10.5000             0     True    False       False       False
# 2   20.0   7.9250             0     True    False        True       False
# 3    6.0  33.0000             1    False     True       False       False
# 4   14.0  11.2417             1    False     True        True       False
#
#     Pclass = 2  Embarked = 2  Embarked = 0  ...  \
# Id                                          ...
# 0        False         False          True  ...
# 1         True          True         False  ...
# 2        False          True         False  ...
# 3         True          True         False  ...
# 4        False         False          True  ...
#
#     Pclass.NUM_UNIQUE(Passengers.Sex)  Pclass.SKEW(Passengers.Age)  \
# Id
# 0                                   2                     0.690926
# 1                                   2                     0.315440
# 2                                   2                     0.690926
# 3                                   2                     0.315440
# 4                                   2                     0.690926
#
#     Pclass.SKEW(Passengers.Fare)  Pclass.SKEW(Passengers.family_count)  \
# Id
# 0                       2.147037                              1.852647
# 1                       2.289693                              0.864271
# 2                       2.147037                              1.852647
# 3                       2.289693                              0.864271
# 4                       2.147037                              1.852647
#
#     Pclass.STD(Passengers.Age)  Pclass.STD(Passengers.Fare)  \
# Id
# 0                    11.122151                     8.792546
# 1                    12.275540                    14.513892
# 2                    11.122151                     8.792546
# 3                    12.275540                    14.513892
# 4                    11.122151                     8.792546
#
#     Pclass.STD(Passengers.family_count)  Pclass.SUM(Passengers.Age)  \
# Id
# 0                              1.659171                     3062.00
# 1                              0.887342                     1280.83
# 2                              1.659171                     3062.00
# 3                              0.887342                     1280.83
# 4                              1.659171                     3062.00
#
#     Pclass.SUM(Passengers.Fare)  Pclass.SUM(Passengers.family_count)
# Id
# 0                     1478.4915                                  109
# 1                      895.1208                                   30
# 2                     1478.4915                                  109
# 3                      895.1208                                   30
# 4                     1478.4915                                  109
#
# [5 rows x 34 columns]

# %%
X_train.shape, X_test.shape
# Out:
# ((668, 34), (223, 34))

# %%
# double check for nulls
for col in X_train.columns:
    if X_train[col].isnull().sum() >0:
        print(col)
        X_train.drop(col, axis=1, inplace=True)

# %%
# Threshold for removing correlated variables
threshold = 0.7

# Absolute value correlation matrix
corr_matrix = X_train.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# Out:
# /var/folders/yc/l505mhd94ws7bth73k_v0xkr0000gn/T/ipykernel_7426/3394482856.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
# Select columns with correlations above threshold
collinear_features = [column for column in upper.columns if any(upper[column] > threshold)]

print('There are %d features to remove.' % (len(collinear_features)))
# Out:
# There are 19 features to remove.

# %%
X_train_flt = X_train.drop(columns = collinear_features)
X_test_flt = X_test.drop(columns = collinear_features)
X_train_flt.shape, X_test_flt.shape
# Out:
# ((668, 15), (223, 15))

# %% [markdown]
# # Modeling

# %%
def run_classification(trainx, testx):
    classifier =DecisionTreeClassifier(criterion='gini',max_depth=2, max_leaf_nodes=20)
    classifier.fit(trainx, y_train)
    Y_pred = classifier.predict(testx)
    print(f"Decision Tree Test score {classifier.score(testx, y_test)}")
    print(f"Decision Tree Confusion Matrix: \n {confusion_matrix(y_test, Y_pred)}")
#     feature_importances = classifier.feature_importances_
#     feature_importances     

    
    lr=LogisticRegression(solver='lbfgs',max_iter=500)
    lr = lr.fit(trainx, y_train)
    print(f"LogisticRegression Test socre {lr.score(testx, y_test)}")
    Y_pred2 = lr.predict(testx)
    print(f"Logistic Regression Confusion Matix:\n {confusion_matrix(y_test, Y_pred2)}")
    
    
    lr_weights = pd.DataFrame({
        'features': testx.columns,
        'importance': lr.coef_[0]
    }) 
    lr_weights.sort_values('importance', ascending=False, inplace=True)
    print(f"LogisticRegression Top Feature Weights\n {lr_weights.head()}")

# %%
run_classification(X_train_flt, X_test_flt)
# Out:
# Decision Tree Test score 0.7757847533632287
# Decision Tree Confusion Matrix:
#  [[127   7]
#  [ 43  46]]
# LogisticRegression Test socre 0.7982062780269058
# Logistic Regression Confusion Matix:
#  [[115  19]
#  [ 26  63]]
# LogisticRegression Top Feature Weights
#                                    features  importance
# 5                               Pclass = 1    0.688766
# 6                               Pclass = 2    0.281283
# 1                                     Fare    0.005010
# 13  Pclass.NUM_UNIQUE(Passengers.Embarked)    0.001167
# 14       Pclass.NUM_UNIQUE(Passengers.Sex)    0.000778
